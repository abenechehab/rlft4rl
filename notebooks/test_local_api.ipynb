# %%
from openai import OpenAI

# %%
client = OpenAI(
    base_url="http://localhost:8001/v1",
    api_key="koala-token",
)

# %%
completion = client.chat.completions.create(
    model="llama-3-2-3b-math-orca-qlora-20k-ep10/final_model",
    messages=[{"role": "user", "content": "Hello!"}],
    max_tokens=100,
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='I\'m not sure I can helpilluminate\n UIScreen\ngeometry\n{\n    color = rgba(250, 220, 190, 1);\n    poly = all;\n    fillRule = evenOdd;\n}\n\nViewport\n{\n    bounds = 0 @ 720p @ 1280;\n    color = rgba(0, 0, 0, 1);\n}\n\nScene\n{\n    llOwnerName = "\\$\\$ yer boi \\$\\$";\n\tcamera {\n\t\t', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[], reasoning_content=None)
