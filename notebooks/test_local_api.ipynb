# %%
from openai import OpenAI

# %%
client = OpenAI(
    base_url="http://localhost:8001/v1",
    api_key="koala-token",
)

# %%
completion = client.chat.completions.create(
    model="models--HuggingFaceTB--SmolLM2-360M-Instruct/snapshots/29ba36fc600930f3cfe6e1a93ab43af299542dc4",
    messages=[{"role": "user", "content": "Hello! what's up buddy?"}],
    max_tokens=100,
)

# %%
print(completion.choices[0].message.content)
# Out:
# Hello! How can I help you today, buddy?
